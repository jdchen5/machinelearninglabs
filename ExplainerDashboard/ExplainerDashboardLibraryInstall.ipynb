# %%
pip install explainerdashboard
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      -------------------------------------- 287.2/287.2 kB 2.9 MB/s eta 0:00:00
# ...
#      ------------------------------------- 448.0/448.0 kB 14.1 MB/s eta 0:00:00
# ...
#      -------------------------------------- 221.2/221.2 kB 6.6 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 57.7/57.7 kB 3.0 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 91.8/91.8 kB 1.7 MB/s eta 0:00:00
# ...
#      --------------------------------------- 10.2/10.2 MB 11.6 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 47.0/47.0 kB 2.5 MB/s eta 0:00:00
# ...
#      -------------------------------------- 145.4/145.4 kB 4.4 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script waitress-serve.exe is installed in 'C:\Users\jdche\AppData\Roaming\Python\Python310\Scripts' which is not on PATH.
# ...
