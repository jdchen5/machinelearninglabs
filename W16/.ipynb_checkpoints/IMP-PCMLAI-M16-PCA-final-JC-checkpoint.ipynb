# %%
import numpy as np
from PIL import Image
from sklearn.decomposition import PCA, KernelPCA
import sklearn
import matplotlib.pyplot as plt

# %% [markdown]
# # Introduction
#
# In this notebook we are going to learn about denoisifying images using PCA. We begin with a simple example of noisy linear observations. We then introduce the fashion MNIST data-set, where we will take some images and artificially add noise. You must then submit a set of exercises related to denoisifying the images using PCA and Kernel PCA.
#
# To try and understand how PCA can help us denoisify, consider the following plot:

# %%
# original data
x = np.linspace(0, 1, 101)
y = 2 * x

# add noise to data
y_noisy = y + np.random.normal(0, 0.2, size = x.shape)

fig, ax = plt.subplots(nrows = 1, ncols = 1)
fig.set_figheight(5)
fig.set_figwidth(10)

ax.scatter(x, y, color = 'r', label = 'original data')
ax.scatter(x, y_noisy, label = 'noisy data')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.legend()

# %% [markdown]
# The plot above shows simple linear data, corrupted by a small amount of Gaussian noise. Can you see why a 1-dimensional representation of the data can help in getting rid of the noise? If we project every noisy data point to the line $y = 2x$, we recover out original data exactly! This is the idea behind PCA denoisifying. This is a simple example, so we are going to explore a more interesting one:

# %% [markdown]
# # Denoisify Fashion-MNIST
#
# We will now try to denoisify data from the fashion MNIST data-set. This is an analogous data set to the MNIST hand written digits set, however it is made up of pictures of different types of clothing. It consists of 10 different labels: t-shirt (0), trouser (1), pullover (2), dress (3), coat (4), sandal (5), shirt (6), sneaker (7), bag (8), ankle boot (9). The code below downloads 5022 images from the data-set and splits into a training and testing data-set. We will then visualize the test set.

# %%
X = np.genfromtxt('data/fashion-mnist_train.csv', delimiter=',')

Y = X[1:, 0]
X_train = X[21:, 1:]
X_test = X[1:21, 1:]

# %%
def plot_images(X, title):
    # we use this function to plot the training images
    fig, axs = plt.subplots(nrows=5, ncols=4, figsize=(8, 8))
    for img, ax in zip(X, axs.ravel()):
        ax.imshow(img.reshape((28, 28)), cmap="Greys")
        ax.axis("off")
    fig.suptitle(title, fontsize=12)

plot_images(X_test, 'Fashion-MNIST')

# %% [markdown]
# We will artificially add noise to the images and display them:

# %%
X_noisy = X_test + np.random.normal(loc = 0, scale = 40, size = X_test.shape)

plot_images(X_noisy, 'Noisy Images')

# %% [markdown]
# To denoisify, we will use the training set to *learn* a low-dimensional space that represents our data, which can be used to remove noise from *similar* images. We can see an example here: https://scikit-learn.org/stable/auto_examples/applications/plot_digits_denoising.html where we use a data-set of uncorrupted digits to remove the noise from corrupted digits.
#
# Note that we treat each image as a flat vector with 784 features. Ideally we want to take bigger advantages of known structure in the images, for example, when flattening the image, we lose a lot of spatial structure (a pixel is closely related to all those around it)!. As an example, the following paper: https://www.researchgate.net/publication/267228169_PCA_based_image_denoising adds filters to the processes to achieve much better results.
#
# Other examples of exploiting image structure will be introduced in Module 21 (Convolutional Neural Networks).

# %% [markdown]
# # Exercises

# %% [markdown]
# The following code will train a PCA model on the training set. It then uses the learned principal components to project the noisy data into a lower dimensional representation, and reconstructs them. We hope this will denoisify the image. However, as you see, it will no be very good. The noise will be gone but the images will not resemble the original. Try increasing the number of principal components to fix this! Play around with it until you get a good denoisification. Answer the following questions:
#
# 1. What is the behavior of the reconstructed images as you include more components?
# **Answer: Starting with 10 components, the reconstructed images captured only the most significant variance of the data and lost many details. They appeared very blurry. As we included more components, the model began to capture a greater amount of variance, incorporating more details from the data. **
# 2. What is the best number of components for denoisifying this particular test set?
# **Answer: 180

# %%
# fit a PCA model
number_of_principal_components = 180 # At Component 180: Total fraction of variance explained by the first 178 variable(s): 0.9502901069170868
pca = PCA(n_components = number_of_principal_components)
pca = pca.fit(X_train)
var = pca.explained_variance_ratio_
var_explained = np.zeros(number_of_principal_components)
for i in range(number_of_principal_components):
    var_explained[i] = sum(var[:i+1])

# transform the noisy data into a lower dimensional representation and then back to a high dimensional one
X_reconstructed_pca = pca.inverse_transform(pca.transform(X_noisy))

# plot the denoisified images
plot_images(X_reconstructed_pca, 'Reconstructed using PCA')


for i in range(number_of_principal_components):
    print("\nComponent", i+1 , "\nFraction of total variance explained by this variable:", var[i],
            "\n Total fraction of variance explained by the first %s variable(s):" % (i +1), var_explained[i] )

plt.figure(figsize = (10,10))
plt.plot(range(1, len(var_explained)+1), var, label = "variance of i th component", marker = "o")
plt.plot(range(1, len(var_explained)+1), var_explained, label = "variance explained by the first i components", marker = "o")
plt.xlabel("comonent i")
plt.ylabel("variance")
plt.title("Scree plot")
plt.legend()
plt.show()
# Out:
# Component 1
# Fraction of total variance explained by this variable: 0.288808923451091
#  Total fraction of variance explained by the first 1 variable(s): 0.288808923451091
#
# Component 2
# Fraction of total variance explained by this variable: 0.17661958188175106
#  Total fraction of variance explained by the first 2 variable(s): 0.4654285053328421
#
# Component 3
# Fraction of total variance explained by this variable: 0.060116661784212155
#  Total fraction of variance explained by the first 3 variable(s): 0.5255451671170542
#
# Component 4
# Fraction of total variance explained by this variable: 0.0509377633355934
#  Total fraction of variance explained by the first 4 variable(s): 0.5764829304526476
#
# Component 5
# Fraction of total variance explained by this variable: 0.0391841116926703
#  Total fraction of variance explained by the first 5 variable(s): 0.615667042145318
#
# Component 6
# Fraction of total variance explained by this variable: 0.03485628544276633
#  Total fraction of variance explained by the first 6 variable(s): 0.6505233275880843
#
# Component 7
# Fraction of total variance explained by this variable: 0.022811848462563233
#  Total fraction of variance explained by the first 7 variable(s): 0.6733351760506475
#
# Component 8
# Fraction of total variance explained by this variable: 0.01934556749885673
#  Total fraction of variance explained by the first 8 variable(s): 0.6926807435495043
#
# Component 9
# Fraction of total variance explained by this variable: 0.014011658645039825
#  Total fraction of variance explained by the first 9 variable(s): 0.7066924021945441
#
# Component 10
# Fraction of total variance explained by this variable: 0.012940883728066583
#  Total fraction of variance explained by the first 10 variable(s): 0.7196332859226107
#
# Component 11
# Fraction of total variance explained by this variable: 0.009741591452599958
#  Total fraction of variance explained by the first 11 variable(s): 0.7293748773752107
#
# Component 12
# Fraction of total variance explained by this variable: 0.00918067300212864
#  Total fraction of variance explained by the first 12 variable(s): 0.7385555503773393
#
# Component 13
# Fraction of total variance explained by this variable: 0.007800156400117479
#  Total fraction of variance explained by the first 13 variable(s): 0.7463557067774568
#
# Component 14
# Fraction of total variance explained by this variable: 0.006543019996092766
#  Total fraction of variance explained by the first 14 variable(s): 0.7528987267735495
#
# Component 15
# Fraction of total variance explained by this variable: 0.006194466176216633
#  Total fraction of variance explained by the first 15 variable(s): 0.7590931929497662
#
# Component 16
# Fraction of total variance explained by this variable: 0.005932894003545975
#  Total fraction of variance explained by the first 16 variable(s): 0.7650260869533122
#
# Component 17
# Fraction of total variance explained by this variable: 0.005600858163146248
#  Total fraction of variance explained by the first 17 variable(s): 0.7706269451164585
#
# Component 18
# Fraction of total variance explained by this variable: 0.005259838491997294
#  Total fraction of variance explained by the first 18 variable(s): 0.7758867836084558
#
# Component 19
# Fraction of total variance explained by this variable: 0.004633475265743761
#  Total fraction of variance explained by the first 19 variable(s): 0.7805202588741995
#
# Component 20
# Fraction of total variance explained by this variable: 0.004595734937820999
#  Total fraction of variance explained by the first 20 variable(s): 0.7851159938120205
#
# Component 21
# Fraction of total variance explained by this variable: 0.004286682575392859
#  Total fraction of variance explained by the first 21 variable(s): 0.7894026763874133
#
# Component 22
# Fraction of total variance explained by this variable: 0.00406138185413871
#  Total fraction of variance explained by the first 22 variable(s): 0.7934640582415521
#
# Component 23
# Fraction of total variance explained by this variable: 0.003896109205619895
#  Total fraction of variance explained by the first 23 variable(s): 0.797360167447172
#
# Component 24
# Fraction of total variance explained by this variable: 0.00372473699858582
#  Total fraction of variance explained by the first 24 variable(s): 0.8010849044457578
#
# Component 25
# Fraction of total variance explained by this variable: 0.003639846756112395
#  Total fraction of variance explained by the first 25 variable(s): 0.8047247512018701
#
# Component 26
# Fraction of total variance explained by this variable: 0.003572410967370562
#  Total fraction of variance explained by the first 26 variable(s): 0.8082971621692407
#
# Component 27
# Fraction of total variance explained by this variable: 0.003362833490908549
#  Total fraction of variance explained by the first 27 variable(s): 0.8116599956601493
#
# Component 28
# Fraction of total variance explained by this variable: 0.003305279142332165
#  Total fraction of variance explained by the first 28 variable(s): 0.8149652748024815
#
# Component 29
# Fraction of total variance explained by this variable: 0.0030984582726317354
#  Total fraction of variance explained by the first 29 variable(s): 0.8180637330751133
#
# Component 30
# Fraction of total variance explained by this variable: 0.002976741526007532
#  Total fraction of variance explained by the first 30 variable(s): 0.8210404746011208
#
# Component 31
# Fraction of total variance explained by this variable: 0.002756380682910734
#  Total fraction of variance explained by the first 31 variable(s): 0.8237968552840316
#
# Component 32
# Fraction of total variance explained by this variable: 0.002703767659152506
#  Total fraction of variance explained by the first 32 variable(s): 0.826500622943184
#
# Component 33
# Fraction of total variance explained by this variable: 0.00265989088677513
#  Total fraction of variance explained by the first 33 variable(s): 0.8291605138299591
#
# Component 34
# Fraction of total variance explained by this variable: 0.002618324854838533
#  Total fraction of variance explained by the first 34 variable(s): 0.8317788386847976
#
# Component 35
# Fraction of total variance explained by this variable: 0.0025003754301582124
#  Total fraction of variance explained by the first 35 variable(s): 0.8342792141149559
#
# Component 36
# Fraction of total variance explained by this variable: 0.0024437303265671334
#  Total fraction of variance explained by the first 36 variable(s): 0.836722944441523
#
# Component 37
# Fraction of total variance explained by this variable: 0.0023208332923938782
#  Total fraction of variance explained by the first 37 variable(s): 0.8390437777339168
#
# Component 38
# Fraction of total variance explained by this variable: 0.00228208740254616
#  Total fraction of variance explained by the first 38 variable(s): 0.841325865136463
#
# Component 39
# Fraction of total variance explained by this variable: 0.00221841490434802
#  Total fraction of variance explained by the first 39 variable(s): 0.8435442800408111
#
# Component 40
# Fraction of total variance explained by this variable: 0.0021139550882457994
#  Total fraction of variance explained by the first 40 variable(s): 0.8456582351290568
#
# Component 41
# Fraction of total variance explained by this variable: 0.0020438490990509384
#  Total fraction of variance explained by the first 41 variable(s): 0.8477020842281078
#
# Component 42
# Fraction of total variance explained by this variable: 0.0019963098457844272
#  Total fraction of variance explained by the first 42 variable(s): 0.8496983940738922
#
# Component 43
# Fraction of total variance explained by this variable: 0.0019511031210406326
#  Total fraction of variance explained by the first 43 variable(s): 0.8516494971949329
#
# Component 44
# Fraction of total variance explained by this variable: 0.0018213110563001437
#  Total fraction of variance explained by the first 44 variable(s): 0.853470808251233
#
# Component 45
# Fraction of total variance explained by this variable: 0.0017796445084482773
#  Total fraction of variance explained by the first 45 variable(s): 0.8552504527596813
#
# Component 46
# Fraction of total variance explained by this variable: 0.0017537748927271577
#  Total fraction of variance explained by the first 46 variable(s): 0.8570042276524085
#
# Component 47
# Fraction of total variance explained by this variable: 0.0017161664703181818
#  Total fraction of variance explained by the first 47 variable(s): 0.8587203941227266
#
# Component 48
# Fraction of total variance explained by this variable: 0.0016809854606030918
#  Total fraction of variance explained by the first 48 variable(s): 0.8604013795833297
#
# Component 49
# Fraction of total variance explained by this variable: 0.0016565390563853628
#  Total fraction of variance explained by the first 49 variable(s): 0.8620579186397151
#
# Component 50
# Fraction of total variance explained by this variable: 0.0016463266303193313
#  Total fraction of variance explained by the first 50 variable(s): 0.8637042452700345
#
# Component 51
# Fraction of total variance explained by this variable: 0.001568221091747571
#  Total fraction of variance explained by the first 51 variable(s): 0.8652724663617821
#
# Component 52
# Fraction of total variance explained by this variable: 0.0014742357112265952
#  Total fraction of variance explained by the first 52 variable(s): 0.8667467020730087
#
# Component 53
# Fraction of total variance explained by this variable: 0.0014583373629754358
#  Total fraction of variance explained by the first 53 variable(s): 0.8682050394359841
#
# Component 54
# Fraction of total variance explained by this variable: 0.001442878357493334
#  Total fraction of variance explained by the first 54 variable(s): 0.8696479177934775
#
# Component 55
# Fraction of total variance explained by this variable: 0.0014216096529272254
#  Total fraction of variance explained by the first 55 variable(s): 0.8710695274464048
#
# Component 56
# Fraction of total variance explained by this variable: 0.0013937715508534922
#  Total fraction of variance explained by the first 56 variable(s): 0.8724632989972583
#
# Component 57
# Fraction of total variance explained by this variable: 0.001373574606647229
#  Total fraction of variance explained by the first 57 variable(s): 0.8738368736039055
#
# Component 58
# Fraction of total variance explained by this variable: 0.0013251574837063538
#  Total fraction of variance explained by the first 58 variable(s): 0.8751620310876118
#
# Component 59
# Fraction of total variance explained by this variable: 0.0013178871775934358
#  Total fraction of variance explained by the first 59 variable(s): 0.8764799182652052
#
# Component 60
# Fraction of total variance explained by this variable: 0.0013000977242915955
#  Total fraction of variance explained by the first 60 variable(s): 0.8777800159894968
#
# Component 61
# Fraction of total variance explained by this variable: 0.0012706762342683383
#  Total fraction of variance explained by the first 61 variable(s): 0.8790506922237652
#
# Component 62
# Fraction of total variance explained by this variable: 0.0012316833349747837
#  Total fraction of variance explained by the first 62 variable(s): 0.88028237555874
#
# Component 63
# Fraction of total variance explained by this variable: 0.0011970123200231086
#  Total fraction of variance explained by the first 63 variable(s): 0.8814793878787631
#
# Component 64
# Fraction of total variance explained by this variable: 0.0011714682071371713
#  Total fraction of variance explained by the first 64 variable(s): 0.8826508560859003
#
# Component 65
# Fraction of total variance explained by this variable: 0.0011553884950670302
#  Total fraction of variance explained by the first 65 variable(s): 0.8838062445809673
#
# Component 66
# Fraction of total variance explained by this variable: 0.001141392891821197
#  Total fraction of variance explained by the first 66 variable(s): 0.8849476374727886
#
# Component 67
# Fraction of total variance explained by this variable: 0.0011255758175279715
#  Total fraction of variance explained by the first 67 variable(s): 0.8860732132903165
#
# Component 68
# Fraction of total variance explained by this variable: 0.0011000986055786195
#  Total fraction of variance explained by the first 68 variable(s): 0.8871733118958951
#
# Component 69
# Fraction of total variance explained by this variable: 0.0010830478070923669
#  Total fraction of variance explained by the first 69 variable(s): 0.8882563597029874
#
# Component 70
# Fraction of total variance explained by this variable: 0.0010675296950444784
#  Total fraction of variance explained by the first 70 variable(s): 0.889323889398032
#
# Component 71
# Fraction of total variance explained by this variable: 0.0010458667383732836
#  Total fraction of variance explained by the first 71 variable(s): 0.8903697561364052
#
# Component 72
# Fraction of total variance explained by this variable: 0.0010404108449003021
#  Total fraction of variance explained by the first 72 variable(s): 0.8914101669813055
#
# Component 73
# Fraction of total variance explained by this variable: 0.0010158218882506615
#  Total fraction of variance explained by the first 73 variable(s): 0.8924259888695562
#
# Component 74
# Fraction of total variance explained by this variable: 0.0009944466044298059
#  Total fraction of variance explained by the first 74 variable(s): 0.893420435473986
#
# Component 75
# Fraction of total variance explained by this variable: 0.0009614947249482163
#  Total fraction of variance explained by the first 75 variable(s): 0.8943819301989342
#
# Component 76
# Fraction of total variance explained by this variable: 0.0009561349297710069
#  Total fraction of variance explained by the first 76 variable(s): 0.8953380651287052
#
# Component 77
# Fraction of total variance explained by this variable: 0.0009253909568582737
#  Total fraction of variance explained by the first 77 variable(s): 0.8962634560855635
#
# Component 78
# Fraction of total variance explained by this variable: 0.0009205127421264291
#  Total fraction of variance explained by the first 78 variable(s): 0.8971839688276899
#
# Component 79
# Fraction of total variance explained by this variable: 0.0009022142247511534
#  Total fraction of variance explained by the first 79 variable(s): 0.898086183052441
#
# Component 80
# Fraction of total variance explained by this variable: 0.0008908878889661169
#  Total fraction of variance explained by the first 80 variable(s): 0.8989770709414071
#
# Component 81
# Fraction of total variance explained by this variable: 0.0008717463447384074
#  Total fraction of variance explained by the first 81 variable(s): 0.8998488172861455
#
# Component 82
# Fraction of total variance explained by this variable: 0.0008696744938247566
#  Total fraction of variance explained by the first 82 variable(s): 0.9007184917799703
#
# Component 83
# Fraction of total variance explained by this variable: 0.0008436910821898689
#  Total fraction of variance explained by the first 83 variable(s): 0.9015621828621602
#
# Component 84
# Fraction of total variance explained by this variable: 0.0008387166956196807
#  Total fraction of variance explained by the first 84 variable(s): 0.9024008995577798
#
# Component 85
# Fraction of total variance explained by this variable: 0.0008236140671019085
#  Total fraction of variance explained by the first 85 variable(s): 0.9032245136248818
#
# Component 86
# Fraction of total variance explained by this variable: 0.0008130409138831432
#  Total fraction of variance explained by the first 86 variable(s): 0.9040375545387649
#
# Component 87
# Fraction of total variance explained by this variable: 0.000802401539839708
#  Total fraction of variance explained by the first 87 variable(s): 0.9048399560786046
#
# Component 88
# Fraction of total variance explained by this variable: 0.0007979952765665017
#  Total fraction of variance explained by the first 88 variable(s): 0.9056379513551711
#
# Component 89
# Fraction of total variance explained by this variable: 0.0007917718532528968
#  Total fraction of variance explained by the first 89 variable(s): 0.906429723208424
#
# Component 90
# Fraction of total variance explained by this variable: 0.00078460303053601
#  Total fraction of variance explained by the first 90 variable(s): 0.9072143262389599
#
# Component 91
# Fraction of total variance explained by this variable: 0.0007702663878343466
#  Total fraction of variance explained by the first 91 variable(s): 0.9079845926267943
#
# Component 92
# Fraction of total variance explained by this variable: 0.000757596286082711
#  Total fraction of variance explained by the first 92 variable(s): 0.9087421889128771
#
# Component 93
# Fraction of total variance explained by this variable: 0.0007523343738552006
#  Total fraction of variance explained by the first 93 variable(s): 0.9094945232867323
#
# Component 94
# Fraction of total variance explained by this variable: 0.0007458311800209094
#  Total fraction of variance explained by the first 94 variable(s): 0.9102403544667532
#
# Component 95
# Fraction of total variance explained by this variable: 0.0007401938825504346
#  Total fraction of variance explained by the first 95 variable(s): 0.9109805483493036
#
# Component 96
# Fraction of total variance explained by this variable: 0.0007199234755060653
#  Total fraction of variance explained by the first 96 variable(s): 0.9117004718248097
#
# Component 97
# Fraction of total variance explained by this variable: 0.0007081237693033046
#  Total fraction of variance explained by the first 97 variable(s): 0.912408595594113
#
# Component 98
# Fraction of total variance explained by this variable: 0.0006893325769548702
#  Total fraction of variance explained by the first 98 variable(s): 0.9130979281710679
#
# Component 99
# Fraction of total variance explained by this variable: 0.0006872614553503506
#  Total fraction of variance explained by the first 99 variable(s): 0.9137851896264183
#
# Component 100
# Fraction of total variance explained by this variable: 0.0006746414449439544
#  Total fraction of variance explained by the first 100 variable(s): 0.9144598310713623
#
# Component 101
# Fraction of total variance explained by this variable: 0.0006692064703487277
#  Total fraction of variance explained by the first 101 variable(s): 0.915129037541711
#
# Component 102
# Fraction of total variance explained by this variable: 0.000654794814104889
#  Total fraction of variance explained by the first 102 variable(s): 0.915783832355816
#
# Component 103
# Fraction of total variance explained by this variable: 0.0006499058562859544
#  Total fraction of variance explained by the first 103 variable(s): 0.916433738212102
#
# Component 104
# Fraction of total variance explained by this variable: 0.0006392048372699738
#  Total fraction of variance explained by the first 104 variable(s): 0.9170729430493719
#
# Component 105
# Fraction of total variance explained by this variable: 0.0006370836410245648
#  Total fraction of variance explained by the first 105 variable(s): 0.9177100266903965
#
# Component 106
# Fraction of total variance explained by this variable: 0.000622215420346271
#  Total fraction of variance explained by the first 106 variable(s): 0.9183322421107427
#
# Component 107
# Fraction of total variance explained by this variable: 0.0006192712612809277
#  Total fraction of variance explained by the first 107 variable(s): 0.9189515133720236
#
# Component 108
# Fraction of total variance explained by this variable: 0.0006073675717444593
#  Total fraction of variance explained by the first 108 variable(s): 0.9195588809437681
#
# Component 109
# Fraction of total variance explained by this variable: 0.0006032354795561514
#  Total fraction of variance explained by the first 109 variable(s): 0.9201621164233242
#
# Component 110
# Fraction of total variance explained by this variable: 0.0005929509248459024
#  Total fraction of variance explained by the first 110 variable(s): 0.9207550673481701
#
# Component 111
# Fraction of total variance explained by this variable: 0.0005850023966257525
#  Total fraction of variance explained by the first 111 variable(s): 0.9213400697447959
#
# Component 112
# Fraction of total variance explained by this variable: 0.0005833275811796144
#  Total fraction of variance explained by the first 112 variable(s): 0.9219233973259755
#
# Component 113
# Fraction of total variance explained by this variable: 0.0005728595095215159
#  Total fraction of variance explained by the first 113 variable(s): 0.922496256835497
#
# Component 114
# Fraction of total variance explained by this variable: 0.0005705430350444909
#  Total fraction of variance explained by the first 114 variable(s): 0.9230667998705414
#
# Component 115
# Fraction of total variance explained by this variable: 0.0005625383027417412
#  Total fraction of variance explained by the first 115 variable(s): 0.9236293381732832
#
# Component 116
# Fraction of total variance explained by this variable: 0.0005557694746193883
#  Total fraction of variance explained by the first 116 variable(s): 0.9241851076479026
#
# Component 117
# Fraction of total variance explained by this variable: 0.0005476586576521509
#  Total fraction of variance explained by the first 117 variable(s): 0.9247327663055548
#
# Component 118
# Fraction of total variance explained by this variable: 0.0005440679132995486
#  Total fraction of variance explained by the first 118 variable(s): 0.9252768342188543
#
# Component 119
# Fraction of total variance explained by this variable: 0.0005358712757658278
#  Total fraction of variance explained by the first 119 variable(s): 0.9258127054946201
#
# Component 120
# Fraction of total variance explained by this variable: 0.0005301637715133304
#  Total fraction of variance explained by the first 120 variable(s): 0.9263428692661335
#
# Component 121
# Fraction of total variance explained by this variable: 0.000526344293358522
#  Total fraction of variance explained by the first 121 variable(s): 0.926869213559492
#
# Component 122
# Fraction of total variance explained by this variable: 0.00051695185875521
#  Total fraction of variance explained by the first 122 variable(s): 0.9273861654182473
#
# Component 123
# Fraction of total variance explained by this variable: 0.000514430504503964
#  Total fraction of variance explained by the first 123 variable(s): 0.9279005959227512
#
# Component 124
# Fraction of total variance explained by this variable: 0.0005128133939821236
#  Total fraction of variance explained by the first 124 variable(s): 0.9284134093167333
#
# Component 125
# Fraction of total variance explained by this variable: 0.0005049584434419419
#  Total fraction of variance explained by the first 125 variable(s): 0.9289183677601752
#
# Component 126
# Fraction of total variance explained by this variable: 0.000502199036803466
#  Total fraction of variance explained by the first 126 variable(s): 0.9294205667969787
#
# Component 127
# Fraction of total variance explained by this variable: 0.000493027485488173
#  Total fraction of variance explained by the first 127 variable(s): 0.9299135942824669
#
# Component 128
# Fraction of total variance explained by this variable: 0.0004896169864924044
#  Total fraction of variance explained by the first 128 variable(s): 0.9304032112689593
#
# Component 129
# Fraction of total variance explained by this variable: 0.00048537653772975085
#  Total fraction of variance explained by the first 129 variable(s): 0.930888587806689
#
# Component 130
# Fraction of total variance explained by this variable: 0.00048203976093323696
#  Total fraction of variance explained by the first 130 variable(s): 0.9313706275676222
#
# Component 131
# Fraction of total variance explained by this variable: 0.00047469665246424933
#  Total fraction of variance explained by the first 131 variable(s): 0.9318453242200865
#
# Component 132
# Fraction of total variance explained by this variable: 0.0004734790708525134
#  Total fraction of variance explained by the first 132 variable(s): 0.932318803290939
#
# Component 133
# Fraction of total variance explained by this variable: 0.000466555361606287
#  Total fraction of variance explained by the first 133 variable(s): 0.9327853586525453
#
# Component 134
# Fraction of total variance explained by this variable: 0.0004619659570692638
#  Total fraction of variance explained by the first 134 variable(s): 0.9332473246096146
#
# Component 135
# Fraction of total variance explained by this variable: 0.0004544312319366381
#  Total fraction of variance explained by the first 135 variable(s): 0.9337017558415512
#
# Component 136
# Fraction of total variance explained by this variable: 0.0004519028676411291
#  Total fraction of variance explained by the first 136 variable(s): 0.9341536587091923
#
# Component 137
# Fraction of total variance explained by this variable: 0.0004457434041580053
#  Total fraction of variance explained by the first 137 variable(s): 0.9345994021133504
#
# Component 138
# Fraction of total variance explained by this variable: 0.00044203750900129093
#  Total fraction of variance explained by the first 138 variable(s): 0.9350414396223516
#
# Component 139
# Fraction of total variance explained by this variable: 0.00043831223875080195
#  Total fraction of variance explained by the first 139 variable(s): 0.9354797518611024
#
# Component 140
# Fraction of total variance explained by this variable: 0.00043342472618634306
#  Total fraction of variance explained by the first 140 variable(s): 0.9359131765872888
#
# Component 141
# Fraction of total variance explained by this variable: 0.0004318727488609832
#  Total fraction of variance explained by the first 141 variable(s): 0.9363450493361498
#
# Component 142
# Fraction of total variance explained by this variable: 0.00042825990635754214
#  Total fraction of variance explained by the first 142 variable(s): 0.9367733092425073
#
# Component 143
# Fraction of total variance explained by this variable: 0.0004230998685970419
#  Total fraction of variance explained by the first 143 variable(s): 0.9371964091111044
#
# Component 144
# Fraction of total variance explained by this variable: 0.00041762817340020746
#  Total fraction of variance explained by the first 144 variable(s): 0.9376140372845045
#
# Component 145
# Fraction of total variance explained by this variable: 0.00041398450298511466
#  Total fraction of variance explained by the first 145 variable(s): 0.9380280217874897
#
# Component 146
# Fraction of total variance explained by this variable: 0.0004105017480328595
#  Total fraction of variance explained by the first 146 variable(s): 0.9384385235355225
#
# Component 147
# Fraction of total variance explained by this variable: 0.0004093413682808766
#  Total fraction of variance explained by the first 147 variable(s): 0.9388478649038033
#
# Component 148
# Fraction of total variance explained by this variable: 0.00040077383445571605
#  Total fraction of variance explained by the first 148 variable(s): 0.939248638738259
#
# Component 149
# Fraction of total variance explained by this variable: 0.00039773014627876504
#  Total fraction of variance explained by the first 149 variable(s): 0.9396463688845378
#
# Component 150
# Fraction of total variance explained by this variable: 0.00039529497693154795
#  Total fraction of variance explained by the first 150 variable(s): 0.9400416638614694
#
# Component 151
# Fraction of total variance explained by this variable: 0.00039022448935299036
#  Total fraction of variance explained by the first 151 variable(s): 0.9404318883508224
#
# Component 152
# Fraction of total variance explained by this variable: 0.00038770814599611
#  Total fraction of variance explained by the first 152 variable(s): 0.9408195964968185
#
# Component 153
# Fraction of total variance explained by this variable: 0.0003829379582610181
#  Total fraction of variance explained by the first 153 variable(s): 0.9412025344550795
#
# Component 154
# Fraction of total variance explained by this variable: 0.00037897512203336685
#  Total fraction of variance explained by the first 154 variable(s): 0.9415815095771128
#
# Component 155
# Fraction of total variance explained by this variable: 0.0003769124213616005
#  Total fraction of variance explained by the first 155 variable(s): 0.9419584219984745
#
# Component 156
# Fraction of total variance explained by this variable: 0.00037377368567351464
#  Total fraction of variance explained by the first 156 variable(s): 0.9423321956841479
#
# Component 157
# Fraction of total variance explained by this variable: 0.00037090016711168925
#  Total fraction of variance explained by the first 157 variable(s): 0.9427030958512597
#
# Component 158
# Fraction of total variance explained by this variable: 0.000367489252205325
#  Total fraction of variance explained by the first 158 variable(s): 0.943070585103465
#
# Component 159
# Fraction of total variance explained by this variable: 0.0003631069690365351
#  Total fraction of variance explained by the first 159 variable(s): 0.9434336920725015
#
# Component 160
# Fraction of total variance explained by this variable: 0.00036051429368644136
#  Total fraction of variance explained by the first 160 variable(s): 0.9437942063661879
#
# Component 161
# Fraction of total variance explained by this variable: 0.00035776291004881183
#  Total fraction of variance explained by the first 161 variable(s): 0.9441519692762368
#
# Component 162
# Fraction of total variance explained by this variable: 0.00035632832723765293
#  Total fraction of variance explained by the first 162 variable(s): 0.9445082976034744
#
# Component 163
# Fraction of total variance explained by this variable: 0.00034746495536001486
#  Total fraction of variance explained by the first 163 variable(s): 0.9448557625588344
#
# Component 164
# Fraction of total variance explained by this variable: 0.0003455406259391424
#  Total fraction of variance explained by the first 164 variable(s): 0.9452013031847736
#
# Component 165
# Fraction of total variance explained by this variable: 0.0003419515069104775
#  Total fraction of variance explained by the first 165 variable(s): 0.9455432546916841
#
# Component 166
# Fraction of total variance explained by this variable: 0.0003406272420010311
#  Total fraction of variance explained by the first 166 variable(s): 0.9458838819336851
#
# Component 167
# Fraction of total variance explained by this variable: 0.0003376614307605642
#  Total fraction of variance explained by the first 167 variable(s): 0.9462215433644456
#
# Component 168
# Fraction of total variance explained by this variable: 0.0003318199251300035
#  Total fraction of variance explained by the first 168 variable(s): 0.9465533632895756
#
# Component 169
# Fraction of total variance explained by this variable: 0.00032898669021161965
#  Total fraction of variance explained by the first 169 variable(s): 0.9468823499797873
#
# Component 170
# Fraction of total variance explained by this variable: 0.00032540219097596705
#  Total fraction of variance explained by the first 170 variable(s): 0.9472077521707633
#
# Component 171
# Fraction of total variance explained by this variable: 0.00032228532224084697
#  Total fraction of variance explained by the first 171 variable(s): 0.9475300374930041
#
# Component 172
# Fraction of total variance explained by this variable: 0.0003203714813400684
#  Total fraction of variance explained by the first 172 variable(s): 0.9478504089743442
#
# Component 173
# Fraction of total variance explained by this variable: 0.00031715445919943986
#  Total fraction of variance explained by the first 173 variable(s): 0.9481675634335437
#
# Component 174
# Fraction of total variance explained by this variable: 0.00031186860952898954
#  Total fraction of variance explained by the first 174 variable(s): 0.9484794320430727
#
# Component 175
# Fraction of total variance explained by this variable: 0.0003101877104627428
#  Total fraction of variance explained by the first 175 variable(s): 0.9487896197535355
#
# Component 176
# Fraction of total variance explained by this variable: 0.0003053178944171008
#  Total fraction of variance explained by the first 176 variable(s): 0.9490949376479526
#
# Component 177
# Fraction of total variance explained by this variable: 0.0003016800242544122
#  Total fraction of variance explained by the first 177 variable(s): 0.9493966176722071
#
# Component 178
# Fraction of total variance explained by this variable: 0.0002970830661417498
#  Total fraction of variance explained by the first 178 variable(s): 0.9496937007383488
#
# Component 179
# Fraction of total variance explained by this variable: 0.00029524176619718975
#  Total fraction of variance explained by the first 179 variable(s): 0.949988942504546
#
# Component 180
# Fraction of total variance explained by this variable: 0.0002919622278455261
#  Total fraction of variance explained by the first 180 variable(s): 0.9502809047323916

# %% [markdown]
# 3. Repeat the exercise above but using Kernel PCA instead. Are you able to achieve better results?
# **Answer: In the instance, I am not able to achieve better results after tried kernel: linear, rbf, poly and cosine. **

# %%
# code here
from sklearn.preprocessing import StandardScaler

# Assuming number_of_principal_components is set to a sensible value
number_of_principal_components = 180  # example value

# Standardize the data
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
#X_noisy_scaled = scaler.transform(X_noisy)


kpca_linear = KernelPCA(n_components = number_of_principal_components, kernel = "linear",fit_inverse_transform=True)
kpca_rbf = KernelPCA(n_components = number_of_principal_components, kernel = "rbf", gamma=0.01, fit_inverse_transform=True)
kpca_poly = KernelPCA(n_components= number_of_principal_components, kernel= "poly", fit_inverse_transform=True)
kpca_cos = KernelPCA(n_components= number_of_principal_components, kernel= "cosine", fit_inverse_transform=True)

#X_linear = kpca_linear.fit_transform(X_train)
#X_rbf = kpca_rbf.fit_transform(X_train)
#X_poly = kpca_poly.fit_transform(X_train)
#X_cos = kpca_cos.fit_transform(X_train)

kpca_linear.fit(X_train_scaled)
kpca_rbf.fit(X_train_scaled)
kpca_poly.fit(X_train_scaled)
kpca_cos.fit(X_train_scaled)



# transform the noisy data into a lower dimensional representation and then back to a high dimensional one
X_linear_reconstructed_pca = kpca_linear.inverse_transform(kpca_linear.transform(X_noisy))
X_rbf_reconstructed_pca = kpca_rbf.inverse_transform(kpca_rbf.transform(X_noisy))
X_poly_reconstructed_pca = kpca_poly.inverse_transform(kpca_poly.transform(X_noisy))
X_cos_reconstructed_pca = kpca_cos.inverse_transform(kpca_cos.transform(X_noisy))

# plot the denoisified images
plot_images(X_linear_reconstructed_pca, 'Reconstructed using PCA, linear')
plot_images(X_rbf_reconstructed_pca, 'Reconstructed using PCA, rbf')
plot_images(X_poly_reconstructed_pca, 'Reconstructed using PCA, poly')
plot_images(X_cos_reconstructed_pca, 'Reconstructed using PCA, cos')

# %% [markdown]
# 4. Finally, we note that the shoes are not always reconstructed well. Assuming you had labelled images, can you think of a way of improving the denoisification process?
# **Answer: With labelled images, we can apply supervised learning techniques. After a broad denoising by PCA, use a logistic regression to correct specific errors in the shoe images.**
