# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import svm
import math
import warnings
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
# use the following to plot SVMs
from mlxtend.plotting import plot_decision_regions # on terminal, install: pip.install mlxtend

# %% [markdown]
# #### Task 1: Support Vector Machines-based classifier on a non-separable dataset
# **Load the 2-D data `Case3rings/X.npy` that has 150 rows and 2 columns, and the corresponding target `Case3rings/y.np`**

# %%
X = np.load('Case3rings/X.npy')
y = np.load('Case3rings/y.npy')
print(X)
print(y)
# Out:
# [[ 2.35281047  0.08003144]
#  [ 2.19172095  0.57502648]
#  [ 2.35742122  0.05772933]
#  [ 2.15387508  0.34823105]
#  [ 1.91525363  0.58441567]
#  [ 1.92895095  0.91492159]
#  [ 2.00894341  0.76765991]
#  [ 1.89462572  0.92632469]
#  [ 2.04651457  0.93136182]
#  [ 1.74512061  0.91046249]
#  [ 1.09994255  1.31653958]
#  [ 1.70497613  1.13714222]
#  [ 1.901419    1.08928489]
#  [ 1.36617053  1.43174665]
#  [ 1.56766118  1.84616468]
#  [ 1.1911033   1.70478441]
#  [ 0.87689379  1.30329157]
#  [ 0.87495972  1.79417652]
#  [ 1.07688816  2.05973996]
#  [ 0.63630708  1.80783517]
#  [ 0.38413016  1.6258009 ]
#  [ 0.13026383  2.33377822]
#  [ 0.24536592  1.88200065]
#  [-0.02888267  2.143175  ]
#  [-0.22761574  1.95518662]
#  [-0.21082524  2.07712875]
#  [-0.26066094  1.75758312]
#  [-0.29026612  2.06530926]
#  [-0.39630989  2.01809927]
#  [-0.65981205  1.85513608]
#  [-0.78862802  1.81809101]
#  [-0.93531951  1.49945207]
#  [-0.852648    1.71163136]
#  [-1.32603967  1.82460726]
# ...

# %% [markdown]
# **Plot the two-dimensional points and color them so that points with the same class have the same color**

# %%
n = 100
color = np.concatenate((np.repeat("blue", n), np.repeat("red",n/2)), axis=0)
plt.scatter(X[:,0], X[:,1], c = color, alpha= .5)
plt.xlabel("X-axis Label")
plt.ylabel("Y-axis Label")
plt.title("Scatter Plot of Data Points")
plt.show()

# %% [markdown]
# **Does a linear SVM based classifier (SVC) sound like a good idea? First discuss, then demonstrate by training, showing the confusion matrix, and plotting the boundary.**

# %% [markdown]
# - Answer: Based on the scatter plot, there is no clear line that can seperate the red points from the blue points without misclassifying several points.

# %%
clf = svm.SVC(kernel = 'linear')
clf.fit(X, y);
cm = confusion_matrix(y,clf.predict(X))
cmd = ConfusionMatrixDisplay(cm,display_labels=np.unique(y))
cmd.plot()

# %%
import warnings
with warnings.catch_warnings(): #otherwise the package will complain there is no "boundary" as we classify all as '1'
    warnings.simplefilter("ignore")
    plot_decision_regions(X, y, clf=clf, legend=2, colors = "red,blue", markers= "o");
    ax=plt.gca();
    plt.show();

# %% [markdown]
# **In the linear SVC case above, why did our model end up classifying every instance with the very same prediction?**

# %% [markdown]
# - Answer: The data points are not linearly distributed. Hence the model classifying every instance with the same prediction.

# %%
#Check the following: #pd.value_counts(y)

# %% [markdown]
# **Try radial Kernel instead (with default parameters) and report the performance, and then plot the decision boundary**
#
# Notes:
# - to change the kernel, try, e.g., `kernel = 'rbf'`
# - to change the cost, try, e.g., `C = 10`
# - to change the scale parameter of RBF, try, e.g., `gamma = 4`
# - see more options in the [official documentation](https://scikit-learn.org/stable/modules/svm.html)

# %%
clf_rbf_c10 = svm.SVC(kernel = 'rbf', C=10)
clf_rbf_c10.fit(X,y);
cm = confusion_matrix(y,clf_rbf_c10.predict(X))
cmd = ConfusionMatrixDisplay(cm,display_labels=np.unique(y))
cmd.plot()

# %%
# plot_decision_regions ...

with warnings.catch_warnings(): #otherwise the package will complain there is no "boundary" as we classify all as '1'
    warnings.simplefilter("ignore")
    plot_decision_regions(X, y, clf=clf_rbf_c10, legend=2, colors = "red,blue", markers= "o");
    ax=plt.gca();
    plt.show();

# %% [markdown]
# **Try raidal Kernel (or RBF) with `gamma = 10`. Interpret the decision boundary.**

# %%
clf_rbf_g10 = svm.SVC(kernel = 'rbf', gamma=10)
clf_rbf_g10.fit(X,y);
cm = confusion_matrix(y,clf_rbf_g10.predict(X))
cmd = ConfusionMatrixDisplay(cm,display_labels=np.unique(y))
cmd.plot()

# %%
# plot_decision_regions ...

with warnings.catch_warnings(): #otherwise the package will complain there is no "boundary" as we classify all as '1'
    warnings.simplefilter("ignore")
    plot_decision_regions(X, y, clf=clf_rbf_c10, legend=2, colors = "red,blue", markers= "o");
    ax=plt.gca();
    plt.show();

# %% [markdown]
# - Answer: The results are very close by changing the C and gamma to 10.

# %% [markdown]
# **Apply the same steps for a polynomial Kernel with degree 3**

# %%
clf_pol_p03 = svm.SVC(kernel = 'poly', degree = 3)
clf_pol_p03.fit(X, y)
cm = confusion_matrix(y, clf_pol_p03.predict(X))
cmd = ConfusionMatrixDisplay(cm, display_labels=np.unique(y))
cmd.plot();

# %%
# plot_decision_regions ...

with warnings.catch_warnings(): #otherwise the package will complain there is no "boundary" as we classify all as '1'
    warnings.simplefilter("ignore")
    plot_decision_regions(X, y, clf=clf_pol_p03, legend=2, colors = "red,blue", markers= "o");
    ax=plt.gca();
    plt.show();

# %% [markdown]
# **Now try polynomial Kernel with degree 8 and cost 1**

# %%
clf_pol_p08c01 = svm.SVC(kernel = 'poly', degree = 8, C=1)
clf_pol_p08c01.fit(X, y)
cm = confusion_matrix(y, clf_pol_p08c01.predict(X))
cmd = ConfusionMatrixDisplay(cm, display_labels=np.unique(y))
cmd.plot();

# %%
# plot_decision_regions ...

with warnings.catch_warnings(): #otherwise the package will complain there is no "boundary" as we classify all as '1'
    warnings.simplefilter("ignore")
    plot_decision_regions(X, y, clf=clf_pol_p08c01, legend=2, colors = "red,blue", markers= "o");
    ax=plt.gca();
    plt.show();

# %% [markdown]
# **Change the cost in the above case to 10**

# %%
clf_pol_p08c10 = svm.SVC(kernel = 'poly', degree = 8, C=10)
clf_pol_p08c10.fit(X, y)
cm = confusion_matrix(y, clf_pol_p08c10.predict(X))
cmd = ConfusionMatrixDisplay(cm, display_labels=np.unique(y))
cmd.plot();

# %%
# plot_decision_regions ...

with warnings.catch_warnings(): #otherwise the package will complain there is no "boundary" as we classify all as '1'
    warnings.simplefilter("ignore")
    plot_decision_regions(X, y, clf=clf_pol_p08c10, legend=2, colors = "red,blue", markers= "o");
    ax=plt.gca();
    plt.show();

# %% [markdown]
# ##### Notes:
# - As you may have realized, the selection for a Kernel is not straightforward
# - The best performing Kernels in this example are polynomial with degree 8 and cost 10, or RBF with gamma 10
# - Moreover, even if we correctly guess RBf with gamma 10 but use a different cost, then our results may get significantly worse.
#
# **To illustrate them final point, run a radial Kernel SVM with gamma 10, but use a cost 0.3.**

# %%
clf_rbf_g10c3 = svm.SVC(kernel = 'rbf', gamma=10, C=0.3)
clf_rbf_g10c3.fit(X,y);
cm = confusion_matrix(y,clf_rbf_g10c3.predict(X))
cmd = ConfusionMatrixDisplay(cm,display_labels=np.unique(y))
cmd.plot()

# %%
# plot_decision_regions ...

with warnings.catch_warnings(): #otherwise the package will complain there is no "boundary" as we classify all as '1'
    warnings.simplefilter("ignore")
    plot_decision_regions(X, y, clf=clf_rbf_g10c3, legend=2, colors = "red,blue", markers= "o");
    ax=plt.gca();
    plt.show();

# %% [markdown]
# **Now use a sigmoid Kernel, display the confusion matrix and plot the decision boundary. Does sigmoid Kernel look like a good match here?**

# %%
clf_sig = svm.SVC(kernel = 'sigmoid')
clf_sig.fit(X,y);
cm = confusion_matrix(y,clf_sig.predict(X))
cmd = ConfusionMatrixDisplay(cm,display_labels=np.unique(y))
cmd.plot()

# %%
with warnings.catch_warnings(): #otherwise the package will complain there is no "boundary" as we classify all as '1'
    warnings.simplefilter("ignore")
    plot_decision_regions(X, y, clf=clf_sig, legend=2, colors = "red,blue", markers= "o");
    ax=plt.gca();
    plt.show();

# %% [markdown]
# - Answer: The sigmoid Kernel is not a good match here.

# %% [markdown]
# **Assume that we will select one of the models we trained above. We compare the accuracy of each model above, and select the best performing model. Are we over- or under-estimating the error of the selecting model? Why? If this is a problem, propose a way to fix this.**

# %% [markdown]
# - Answer: We might overestimating the error of the selected model. This is because we were testing the model on the same data it was trained on, which can lead to overfitting. Using K-fold cross-validation and train the model K times.
